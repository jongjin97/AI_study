# %% [markdown]
# # BERT의 워드피스 토크나이저(BertWordPieceTokenizer)

# %%
import pandas as pd
import urllib.request
from tokenizers import BertWordPieceTokenizer

urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings.txt", filename="ratings.txt")
# Out:
# ('ratings.txt', <http.client.HTTPMessage at 0x79128ad33010>)

# %%
naver_df = pd.read_table('ratings.txt')
naver_df = naver_df.dropna(how='any')
with open('naver_review.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(naver_df['document']))

# %%
tokenizer = BertWordPieceTokenizer(lowercase=False)

# %%
data_file = 'naver_review.txt'
vocab_size = 30000
limit_alphabet = 6000
min_frequency = 5

tokenizer.train(files=data_file,
                vocab_size=vocab_size,
                limit_alphabet=limit_alphabet,
                min_frequency=min_frequency)

# %%
# vocab 저장
tokenizer.save_model('./')
# Out:
# ['./vocab.txt']

# %%
# vocab 로드
df = pd.read_fwf('vocab.txt', header=None)
df
# Out:
#             0
# 0       [PAD]
# 1       [UNK]
# 2       [CLS]
# 3       [SEP]
# 4      [MASK]
# ...       ...
# 29995      말세
# 29996      말과
# 29997     말들이
# 29998     말라는
# 29999    말밖에는
#
# [30000 rows x 1 columns]

# %%
encoded = tokenizer.encode('아 배고픈데 짜장면먹고싶다')
print('토큰화 결과 :',encoded.tokens)
print('정수 인코딩 :',encoded.ids)
print('디코딩 :',tokenizer.decode(encoded.ids))
# Out:
# 토큰화 결과 : ['아', '배고', '##픈', '##데', '짜장면', '##먹고', '##싶다']
# 정수 인코딩 : [2111, 20630, 3985, 3337, 24683, 7873, 7378]
# 디코딩 : 아 배고픈데 짜장면먹고싶다

# %%
encoded = tokenizer.encode('커피 한잔의 여유를 즐기다')
print('토큰화 결과 :',encoded.tokens)
print('정수 인코딩 :',encoded.ids)
print('디코딩 :',tokenizer.decode(encoded.ids))
# Out:
# 토큰화 결과 : ['커피', '한잔', '##의', '여유', '##를', '즐기', '##다']
# 정수 인코딩 : [12825, 25645, 3295, 12696, 3440, 10784, 3241]
# 디코딩 : 커피 한잔의 여유를 즐기다
